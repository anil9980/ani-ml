# %% [markdown]
# **variables**

# %%
x=5

# %%
x
# Out:
# 5

# %%
print(x)
# Out:
# 5

# %%
x=3
y='anil'
z='c'
a="kumar"
b=5.0
print(x,y,z,a,b)
print(b)
# Out:
# 3 anil c kumar 5.0
# 5.0

# %%
type(x)
print(type(x))
y=True
type(y)
print(type(y))
# Out:
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# **airthmetic operations**

# %%
# +  -  *  /  ** % //

# %%
a=2
b=4
c=2
d=8
print(a+b)
print(b-a)
print(b*c)
print(b/c)
print(a**b)
print(d//a)
print(a+b*c/a)
# Out:
# 6
# 2
# 8
# 2.0
# 16
# 4
# 6.0

# %% [markdown]
# **Assignment operator**
#   *= += -= *= /= **= //=*

# %%
a=12
print(a)
a += 2
print(a)
a -= 2
print(a)
a *= 2
print(a)
a /= 2
print(a)
a //= 4
print(a)
a **= 2
print(a)
# Out:
# 12
# 14
# 12
# 24
# 12.0
# 3.0
# 9.0
